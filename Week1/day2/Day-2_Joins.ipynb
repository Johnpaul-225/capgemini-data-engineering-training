-- %% [markdown]
-- ## Creating employee Table and Inserting values

-- %%
%sql
drop table if exists employees;
CREATE TABLE employees (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
manager_id INT,
dept_id INT
);
INSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES
(1, 'Karthik', NULL, 1),
(2, 'Ajay', 1, 1),
(3, 'Vijay', 1, 2),
(4, 'Vinay', 2, 2),
(5, 'Meena', 3, 3),
(6, 'Veer', NULL, 4),
(7, 'Keerthi', 4, 5),
(8, 'Priya', 4, 5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Creating Department Table and Inserting Values

-- %%
CREATE TABLE departments (
dept_id INT PRIMARY KEY,
dept_name VARCHAR(50)
);

INSERT INTO departments (dept_id, dept_name) VALUES
(1, 'HR'),
(2, 'IT'),
(3, 'Finance'),
(4, 'Marketing'),
(5, 'Sales');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Creating Project Table and Inserting Values

-- %%
CREATE TABLE projects (
project_id INT PRIMARY KEY,
project_name VARCHAR(50),
emp_id INT
);

INSERT INTO projects (project_id, project_name, emp_id) VALUES
(1, 'Project A', 1),
(2, 'Project B', 2),
(3, 'Project C', 3),
(4, 'Project D', 4),
(5, 'Project E', 5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Displaying Employee table

-- %%
select * from employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>manager_id</th><th>dept_id</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>null</td><td>1</td></tr><tr><td>2</td><td>Ajay</td><td>1</td><td>1</td></tr><tr><td>3</td><td>Vijay</td><td>1</td><td>2</td></tr><tr><td>4</td><td>Vinay</td><td>2</td><td>2</td></tr><tr><td>5</td><td>Meena</td><td>3</td><td>3</td></tr><tr><td>6</td><td>Veer</td><td>null</td><td>4</td></tr><tr><td>7</td><td>Keerthi</td><td>4</td><td>5</td></tr><tr><td>8</td><td>Priya</td><td>4</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Displaying Department table

-- %%
select * from departments;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_id</th><th>dept_name</th></tr></thead><tbody><tr><td>1</td><td>HR</td></tr><tr><td>2</td><td>IT</td></tr><tr><td>3</td><td>Finance</td></tr><tr><td>4</td><td>Marketing</td></tr><tr><td>5</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Displaying Project Table

-- %%
select * from projects
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project_id</th><th>project_name</th><th>emp_id</th></tr></thead><tbody><tr><td>1</td><td>Project A</td><td>1</td></tr><tr><td>2</td><td>Project B</td><td>2</td></tr><tr><td>3</td><td>Project C</td><td>3</td></tr><tr><td>4</td><td>Project D</td><td>4</td></tr><tr><td>5</td><td>Project E</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 1. Retrieve the names of employees and their corresponding managers from the "employees" table, ensuring that even employees without managers are included.

-- %%
select E.emp_name as Employee_Name, coalesce(E1.emp_name,"No Manger") as Manger_name
From employees E
left join employees E1
on E.manager_id = E1.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>Manger_name</th></tr></thead><tbody><tr><td>Karthik</td><td>No Manger</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Veer</td><td>No Manger</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr><tr><td>Priya</td><td>Vinay</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2. Display all employees and their corresponding departments from the "employees" and "departments" tables, showing employees even if they don't belong to any department.

-- %%
select E.emp_name, D.dept_name
From employees E
left join departments D
on E.dept_id = D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 3. List the names of employees who report to a manager, along with their manager's name, fromthe "employees" table.

-- %%
select E.emp_name as Employee_Name, E1.emp_name as Manger_name
From employees E
inner join employees E1
on E.manager_id = E1.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>Manger_name</th></tr></thead><tbody><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Priya</td><td>Vinay</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 5. Display a list of employees who do not belong to any department, even if the department data is missing.

-- %%
select E.emp_name as Employee_Name, D.dept_name
From employees E
inner join departments D
on E.dept_id = D.dept_id
where E.emp_id == D.dept_id==NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>dept_name</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 6. Fetch the names of employees and the projects they are assigned to. For employees who are not assigned any projects, show NULL for the project

-- %%
select E.emp_name as Employee_Name, P.project_name
From employees E
left join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 7. List all employees who have completed at least one project, showing their names and the
-- project names.
-- ###

-- %%
select E.emp_name as Employee_Name, P.project_name
From employees E
inner join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 8. Show the names of employees and their projects, ensuring that no project is omitted even if an employee is not assigned to it.

-- %%
select E.emp_name as Employee_Name, P.project_name
From employees E
left join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Retrieve the names of employees and their corresponding department names, including employees who are not in any department.

-- %%
select E.emp_name as Employee_Name, D.dept_name
From employees E
left join departments D
on E.dept_id = D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_Name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 11. Find the names of all departments and employees, ensuring that departments with no employees are included.

-- %%
select D.dept_name, E.emp_name
From employees E
left join departments D
on E.dept_id = D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>emp_name</th></tr></thead><tbody><tr><td>HR</td><td>Karthik</td></tr><tr><td>HR</td><td>Ajay</td></tr><tr><td>IT</td><td>Vijay</td></tr><tr><td>IT</td><td>Vinay</td></tr><tr><td>Finance</td><td>Meena</td></tr><tr><td>Marketing</td><td>Veer</td></tr><tr><td>Sales</td><td>Keerthi</td></tr><tr><td>Sales</td><td>Priya</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 13. Show the names of employees and their department names, including employees not assigned

-- %%
select  E.emp_name, D.dept_name
From employees E
full outer join departments D
on E.dept_id = D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Veer</td><td>Marketing</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 14. Find employees who have not completed any project, along with the project details where applicable.

-- %%
select E.emp_name
From employees E
inner join projects p
where P.project_id is NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### 15. Retrieve the names of employees and the names of their projects, including employees who are not working on any project.

-- %%
select E.emp_name, P.project_name
From employees E
LEFT join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 16. List all projects and the employees assigned to them, even for projects that have no employees.

-- %%
select P.project_name, E.emp_name
From employees E
right join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project_name</th><th>emp_name</th></tr></thead><tbody><tr><td>Project A</td><td>Karthik</td></tr><tr><td>Project B</td><td>Ajay</td></tr><tr><td>Project C</td><td>Vijay</td></tr><tr><td>Project D</td><td>Vinay</td></tr><tr><td>Project E</td><td>Meena</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 17. Show the names of all employees who have both a manager and at least one project, listing the manager's name as well.

-- %%
select E.emp_name, E1.manager_id
From employees E
inner join projects p
on E.emp_id = P.emp_id
inner join employees E1
on E.emp_id = E1.manager_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_id</th></tr></thead><tbody><tr><td>Karthik</td><td>1</td></tr><tr><td>Ajay</td><td>2</td></tr><tr><td>Vijay</td><td>3</td></tr><tr><td>Vinay</td><td>4</td></tr><tr><td>Karthik</td><td>1</td></tr><tr><td>Vinay</td><td>4</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 18. List the names of employees and the corresponding department names, but exclude those employees who don't belong to a department.

-- %%
select E.emp_name, D.dept_name
From employees E
inner join departments D
on E.dept_id = D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- ###  19. Display employees who belong to multiple departments, showing the employee's name and the department names.

-- %%
select E.emp_name, D.dept_name
From employees E
join departments D
on E.dept_id = D.dept_id
where E.emp_id IN(
  select emp_id
  from employees
  group by emp_id
  having count(Distinct(dept_id)) > 1
)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 20. List the names of all departments and employees, ensuring that even if a department has no employees, it is included in the result.

-- %%
select E.emp_name, D.dept_name
From employees E
right join departments D
on E.dept_id = D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Priya</td><td>Sales</td></tr><tr><td>Karthik</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Keerthi</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 21. Retrieve employees who have worked on at least one project and do not belong to a department, listing their name and project details.

-- %%
select E.emp_name, P.project_name
From employees E
join projects P
on E.emp_id = P.emp_id
where E.dept_id IS NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 22. Find the total number of employees who belong to a department, ensuring the departments with no employees are still included.

-- %%
select D.dept_name, count(E.emp_id) as tot_no_of_emp
From departments D
left join Employees e on D.dept_id = E.dept_id
group by D.dept_name
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>tot_no_of_emp</th></tr></thead><tbody><tr><td>Sales</td><td>2</td></tr><tr><td>IT</td><td>2</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>Finance</td><td>1</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 23. Show the employees and their managers, displaying only those employees who report to a manager, excluding employees without managers.

-- %%
select E.emp_name as Emp_name, E1.emp_name as Manager_name
from employees E
inner join employees E1
on E.emp_id=E1.manager_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Vijay</td></tr><tr><td>Ajay</td><td>Vinay</td></tr><tr><td>Vijay</td><td>Meena</td></tr><tr><td>Vinay</td><td>Priya</td></tr><tr><td>Karthik</td><td>Ajay</td></tr><tr><td>Vinay</td><td>Keerthi</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 24. Display all employee names along with their corresponding managers' names, but includeemployees who do not have managers.

-- %%
select E.emp_name as Emp_name, E1.emp_name as Manager_name
from employees E
left join employees E1
on E.emp_id=E1.manager_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Vijay</td></tr><tr><td>Ajay</td><td>Vinay</td></tr><tr><td>Vijay</td><td>Meena</td></tr><tr><td>Vinay</td><td>Priya</td></tr><tr><td>Meena</td><td>null</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr><tr><td>Karthik</td><td>Ajay</td></tr><tr><td>Vinay</td><td>Keerthi</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 25. Find the names of departments and the number of employees in each department, including departments that have no employees.

-- %%
select D.dept_name, count(E.emp_id) as tot_no_of_emp
From departments D
left join Employees e on D.dept_id = E.dept_id
group by D.dept_name
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>tot_no_of_emp</th></tr></thead><tbody><tr><td>Sales</td><td>2</td></tr><tr><td>IT</td><td>2</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>Finance</td><td>1</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 26. List all employees and the departments they belong to, ensuring that departments with no employees are also listed.

-- %%
select D.dept_name, E.emp_name
From departments D
left join Employees e on D.dept_id = E.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>emp_name</th></tr></thead><tbody><tr><td>HR</td><td>Ajay</td></tr><tr><td>IT</td><td>Vinay</td></tr><tr><td>Finance</td><td>Meena</td></tr><tr><td>Marketing</td><td>Veer</td></tr><tr><td>Sales</td><td>Priya</td></tr><tr><td>HR</td><td>Karthik</td></tr><tr><td>IT</td><td>Vijay</td></tr><tr><td>Sales</td><td>Keerthi</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 28. Retrieve the names of employees and their project assignments, including employees who are not assigned to any projects.

-- %%
select E.emp_name, P.project_name
From employees E
left join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 29. List the names of all employees and their respective department and project assignments, including employees who are not assigned to a project or department.

-- %%
select E.emp_name, D.dept_name, P.project_name
From employees E
left join departments D
on E.dept_id = D.dept_id
left join projects P
on E.emp_id = P.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td><td>Project A</td></tr><tr><td>Ajay</td><td>HR</td><td>Project B</td></tr><tr><td>Vijay</td><td>IT</td><td>Project C</td></tr><tr><td>Vinay</td><td>IT</td><td>Project D</td></tr><tr><td>Meena</td><td>Finance</td><td>Project E</td></tr><tr><td>Veer</td><td>Marketing</td><td>null</td></tr><tr><td>Keerthi</td><td>Sales</td><td>null</td></tr><tr><td>Priya</td><td>Sales</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 30. Display the names of employees who belong to at least one department, with the department name listed, but include employees without a department as well

-- %%
select E.emp_name, D.dept_name
From employees E
left join departments D
on E.dept_id=D.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- ####
