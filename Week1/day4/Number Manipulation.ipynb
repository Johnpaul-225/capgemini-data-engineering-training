-- %% [markdown]
-- ##  Creating Employee Salary table and Inserting Values

-- %%
CREATE TABLE employee_salary (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
base_salary DECIMAL(10,2),
bonus DECIMAL(10,2),
tax_percent DECIMAL(5,2),
experience_years INT
);
INSERT INTO employee_salary VALUES
(1, 'Karthik', 75000.75, 5000.50, 10.00, 6),
(2, 'Veena', 65000.40, 4000.25, 8.50, 4),
(3, 'Ravi', 85000.90, 6000.75, 12.00, 8),
(4, 'Anil', 70000.10, NULL, 9.00, 5),
(5, 'Suresh', 60000.55, 3000.30, 7.50, 3);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Displaying of table

-- %%
select * from employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>base_salary</th><th>bonus</th><th>tax_percent</th><th>experience_years</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>75000.75</td><td>5000.50</td><td>10.00</td><td>6</td></tr><tr><td>2</td><td>Veena</td><td>65000.40</td><td>4000.25</td><td>8.50</td><td>4</td></tr><tr><td>3</td><td>Ravi</td><td>85000.90</td><td>6000.75</td><td>12.00</td><td>8</td></tr><tr><td>4</td><td>Anil</td><td>70000.10</td><td>null</td><td>9.00</td><td>5</td></tr><tr><td>5</td><td>Suresh</td><td>60000.55</td><td>3000.30</td><td>7.50</td><td>3</td></tr></tbody></table></div>

-- %%
SELECT ABS(-100);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ABS(-100)</th></tr></thead><tbody><tr><td>100</td></tr></tbody></table></div>

-- %%
SELECT ROUND(base_salary, 0) FROM employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ROUND(base_salary,0)</th></tr></thead><tbody><tr><td>75001</td></tr><tr><td>65000</td></tr><tr><td>85001</td></tr><tr><td>70000</td></tr><tr><td>60001</td></tr></tbody></table></div>

-- %%
SELECT ROUND(base_salary, 2) FROM employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ROUND(base_salary,2)</th></tr></thead><tbody><tr><td>75000.75</td></tr><tr><td>65000.40</td></tr><tr><td>85000.90</td></tr><tr><td>70000.10</td></tr><tr><td>60000.55</td></tr></tbody></table></div>

-- %%
SELECT CEIL(base_salary) FROM employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CEIL(base_salary)</th></tr></thead><tbody><tr><td>75001</td></tr><tr><td>65001</td></tr><tr><td>85001</td></tr><tr><td>70001</td></tr><tr><td>60001</td></tr></tbody></table></div>

-- %%
SELECT FLOOR(base_salary) FROM employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FLOOR(base_salary)</th></tr></thead><tbody><tr><td>75000</td></tr><tr><td>65000</td></tr><tr><td>85000</td></tr><tr><td>70000</td></tr><tr><td>60000</td></tr></tbody></table></div>

-- %%
SELECT MOD(experience_years, 2) FROM employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MOD(experience_years,2)</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>0</td></tr><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>1</td></tr></tbody></table></div>

-- %%
SELECT POWER(2, 3)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>POWER(2,3)</th></tr></thead><tbody><tr><td>8.0</td></tr></tbody></table></div>

-- %%
SELECT POW(5, 2)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>POW(5,2)</th></tr></thead><tbody><tr><td>25.0</td></tr></tbody></table></div>

-- %%
SELECT SQRT(64)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SQRT(64)</th></tr></thead><tbody><tr><td>8.0</td></tr></tbody></table></div>

-- %%
SELECT SIGN(base_salary) FROM employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SIGN(base_salary)</th></tr></thead><tbody><tr><td>1.0</td></tr><tr><td>1.0</td></tr><tr><td>1.0</td></tr><tr><td>1.0</td></tr><tr><td>1.0</td></tr></tbody></table></div>

-- %%
SELECT RAND()
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>RAND()</th></tr></thead><tbody><tr><td>0.3907694227836631</td></tr></tbody></table></div>

-- %%
SELECT emp_name,
GREATEST(base_salary, IFNULL(bonus, 0)) as greatest
from employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>greatest</th></tr></thead><tbody><tr><td>Karthik</td><td>75000.75</td></tr><tr><td>Veena</td><td>65000.40</td></tr><tr><td>Ravi</td><td>85000.90</td></tr><tr><td>Anil</td><td>70000.10</td></tr><tr><td>Suresh</td><td>60000.55</td></tr></tbody></table></div>

-- %%
SELECT emp_name,
LEAST(base_salary, IFNULL(bonus, 0)) as least_value
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>least_value</th></tr></thead><tbody><tr><td>Karthik</td><td>5000.50</td></tr><tr><td>Veena</td><td>4000.25</td></tr><tr><td>Ravi</td><td>6000.75</td></tr><tr><td>Anil</td><td>0.00</td></tr><tr><td>Suresh</td><td>3000.30</td></tr></tbody></table></div>
